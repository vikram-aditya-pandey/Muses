# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:/Users/adity/Downloads/ex.csv")

# %%
df.isnull().sum()
# Out:
# Song-Name          0
# Singer/Artists    10
# Genre              0
# Album/Movie        3
# User-Rating        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 16

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#           Song-Name                                    Singer/Artists  \
# 0       Aankh Marey               Kumar Sanu, Mika Singh, Neha Kakkar
# 1         Coca Cola                          Neha Kakkar, Tony Kakkar
# 2  Apna Time Aayega                                     Ranveer Singh
# 3            Mungda             Jyotica Tangri, Shaan, Subhro Ganguly
# 4          Tere Bin  Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
#
#                     Genre    Album/Movie User-Rating
# 0          BollywoodDance         Simmba      8.8/10
# 1  BollywoodDanceRomantic    Luka Chuppi      9.0/10
# 2          BollywoodDance      Gully Boy      9.7/10
# 3          BollywoodDance  Total Dhamaal      9.1/10
# 4       BollywoodRomantic         Simmba      9.2/10

# %%
df['User-Rating']
# Out:
# 0       8.8/10
# 1       9.0/10
# 2       9.7/10
# 3       9.1/10
# 4       9.2/10
#          ...
# 2415    6.2/10
# 2416    7.2/10
# 2417    7.5/10
# 2418    6.5/10
# 2419    6.6/10
# Name: User-Rating, Length: 2391, dtype: object

# %%
l=[]
for i in df['User-Rating']:
    l.append(i[1:3])
l
# Out:
# ['.8',
#  '.0',
#  '.7',
#  '.1',
#  '.2',
#  '.1',
#  '.2',
#  '.5',
#  '.2',
#  '.6',
#  '.8',
#  '.4',
#  '.1',
#  '.2',
#  '.0',
#  '.7',
#  '.1',
#  '.0',
#  '.0',
#  '.1',
#  '.2',
#  '.2',
#  '.5',
#  '.6',
#  '.1',
#  '.0',
#  '.0',
#  '.2',
#  '.5',
#  '.4',
#  '.7',
#  '.3',
#  '.3',
#  '.5',
#  '.1',
#  '.0',
#  '.0',
#  '.1',
#  '.4',
#  '.4',
#  '.8',
#  '.2',
#  '.2',
#  '.6',
#  '.6',
#  '.0',
#  '.1',
#  '.5',
#  '.5',
#  '.5',
#  '.7',
#  '.9',
#  '.6',
#  '.5',
#  '.1',
#  '.7',
#  '.6',
#  '.3',
#  '.7',
#  '.9',
#  '.0',
#  '.0',
#  '.3',
#  '.3',
#  '.1',
#  '.0',
#  '.7',
#  '.2',
#  '.1',
#  '.0',
#  '.9',
#  '.5',
#  '.5',
#  '.7',
#  '.0',
#  '.1',
#  '.1',
#  '.5',
#  '.1',
#  '.6',
#  '.4',
#  '.0',
#  '.0',
#  '.6',
#  '.3',
#  '.0',
#  '.2',
#  '.3',
#  '.1',
#  '.6',
#  '.5',
#  '.5',
#  '.0',
#  '.4',
#  '.2',
#  '.6',
#  '.3',
#  '.7',
#  '.2',
#  '.3',
#  '.7',
#  '.0',
#  '.5',
#  '.4',
#  '.0',
#  '.2',
#  '.0',
#  '.4',
#  '.4',
#  '.1',
#  '.3',
# ...

# %%
df['User-Rating']=l

# %%
df
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                         Singer/Artists  \
# 0                  Kumar Sanu, Mika Singh, Neha Kakkar
# 1                             Neha Kakkar, Tony Kakkar
# 2                                        Ranveer Singh
# 3                Jyotica Tangri, Shaan, Subhro Ganguly
# 4     Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
# ...                                                ...
# 2415                                            Mukesh
# ...

# %%
df['Singer/Artists']=df['Singer/Artists'].str.replace(' ',' ')
df['Album/Movie']=df['Album/Movie'].str.replace(' ',' ')
df
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                         Singer/Artists  \
# 0                  Kumar Sanu, Mika Singh, Neha Kakkar
# 1                             Neha Kakkar, Tony Kakkar
# 2                                        Ranveer Singh
# 3                Jyotica Tangri, Shaan, Subhro Ganguly
# 4     Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
# ...                                                ...
# 2415                                            Mukesh
# ...

# %%
df['Singer/Artists']=df['Singer/Artists'].str.replace(',',' ')
df['Album/Movie']=df['Album/Movie'].str.replace(',',' ')
df
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                         Singer/Artists  \
# 0                  Kumar Sanu  Mika Singh  Neha Kakkar
# 1                             Neha Kakkar  Tony Kakkar
# 2                                        Ranveer Singh
# 3                Jyotica Tangri  Shaan  Subhro Ganguly
# 4     Asees Kaur  Rahat Fateh Ali Khan  Tanishk Bagchi
# ...                                                ...
# 2415                                            Mukesh
# ...

# %%
df['tags']=df['Singer/Artists']+df['Genre']+df['Album/Movie']+df['User-Rating']
df
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                         Singer/Artists  \
# 0                  Kumar Sanu  Mika Singh  Neha Kakkar
# 1                             Neha Kakkar  Tony Kakkar
# 2                                        Ranveer Singh
# 3                Jyotica Tangri  Shaan  Subhro Ganguly
# 4     Asees Kaur  Rahat Fateh Ali Khan  Tanishk Bagchi
# ...                                                ...
# 2415                                            Mukesh
# ...

# %%
df0=df[['Song-Name','tags']]
df0
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                                    tags
# 0     Kumar Sanu  Mika Singh  Neha KakkarBollywoodDa...
# 1     Neha Kakkar  Tony KakkarBollywoodDanceRomantic...
# 2                Ranveer SinghBollywoodDanceGully Boy.7
# 3     Jyotica Tangri  Shaan  Subhro GangulyBollywood...
# 4     Asees Kaur  Rahat Fateh Ali Khan  Tanishk Bagc...
# ...                                                 ...
# 2415                      MukeshBollywoodDanceSasural.2
# ...

# %%
df0['tags']=df0['tags'].apply(lambda x:x.lower())
df0
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_2996\2395046704.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0['tags']=df0['tags'].apply(lambda x:x.lower())
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                                    tags
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=2000)

# %%
vectors=cv.fit_transform(df0['tags']).toarray()

# %%
vectors.shape
# Out:
# (2391, 2000)

# %%
cv.get_feature_names_out()
# Out:
# array(['aakanksha', 'aaman', 'aana', ..., 'zinda', 'zindagi', 'zubeen'],
#       dtype=object)

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity=cosine_similarity(vectors)

# %%
sorted(list(enumerate(similarity[0])),reverse=True,key=lambda x:x[1])
# Out:
# [(0, 1.0),
#  (2125, 0.5477225575051662),
#  (136, 0.5163977794943223),
#  (202, 0.5163977794943223),
#  (1241, 0.5163977794943223),
#  (1790, 0.5163977794943223),
#  (1911, 0.5163977794943223),
#  (5, 0.4472135954999579),
#  (374, 0.4472135954999579),
#  (406, 0.4472135954999579),
#  (407, 0.4472135954999579),
#  (603, 0.4472135954999579),
#  (919, 0.4472135954999579),
#  (1045, 0.4472135954999579),
#  (1296, 0.4472135954999579),
#  (1515, 0.4472135954999579),
#  (1609, 0.4472135954999579),
#  (1819, 0.4472135954999579),
#  (1823, 0.4472135954999579),
#  (1873, 0.4472135954999579),
#  (1957, 0.4472135954999579),
#  (2199, 0.4472135954999579),
#  (2245, 0.4472135954999579),
#  (11, 0.39999999999999997),
#  (54, 0.39999999999999997),
#  (1108, 0.39999999999999997),
#  (1111, 0.39999999999999997),
#  (1653, 0.39999999999999997),
#  (1863, 0.39999999999999997),
#  (608, 0.36514837167011077),
#  (1229, 0.36514837167011077),
#  (1436, 0.36514837167011077),
#  (367, 0.3380617018914066),
# ...

# %%
df0.rename(columns={'Song-Name':'title'},inplace=True)
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_2996\2449279074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0.rename(columns={'Song-Name':'title'},inplace=True)

# %%
def recommend(music):
    music_index=df0[df0['title']==music].index[0]
    distances=similarity[music_index]
    music_list=sorted(list(enumerate(distance)),reverse=True,key=lambda x:x[1])[1:6]
    for i in music_list:
        print(df0.iloc[i[0]].title)

# %%
df.head(50)
# Out:
#                           Song-Name  \
# 0                       Aankh Marey
# 1                         Coca Cola
# 2                  Apna Time Aayega
# 3                            Mungda
# 4                          Tere Bin
# 5                         Gali Gali
# 6                     Chamma Chamma
# 7                   Mere Gully Mein
# 8                          Kamariya
# 9   Ek Ladki Ko Dekha Toh Aisa Laga
# 10                   Swag Se Swagat
# 11                  Poster Lagwa Do
# 12                      Daaru Wargi
# 13                           Dilbar
# 14                    Proper Patola
# 15                            Doori
# 16                 Dil Diyan Gallan
# 17                     Husn Parcham
# 18                  Bom Diggy Diggy
# 19                       Issaqbaazi
# 20                     Mere Naam Tu
# 21    High Rated Gabru – Nawabzaade
# 22                    Dekhte Dekhte
# 23                          Zingaat
# 24                         Tareefan
# ...

# %%
import pickle 
pickle.dump(df0,open('musicrec.pkl','wb'))

# %%
pickle.dump(similarity,open('similarities.pkl','wb'))
